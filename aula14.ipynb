# %%
# %pip install kivymd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.6 MB/s eta 0:00:00:00:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 23.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 21.1 MB/s eta 0:00:00
# ...
#   Created wheel for kivymd: filename=kivymd-1.2.0-py3-none-any.whl size=2235620 sha256=668734d7631241d0a69e94d95adda8fcd78d0ee82771eec0f6fcc278567955bf
#   Stored in directory: /home/raphael/.cache/pip/wheels/05/31/28/473ae8293cc8160932fbf4610992b66a6ba4336f8f5f9af6cf
# Successfully built kivymd
# ...
# Note: you may need to restart the kernel to use updated packages.
